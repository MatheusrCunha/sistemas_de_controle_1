# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusrCunha/sistemas_de_controle_1/blob/main/Sistemas_de_Controle1_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import control as ctl
except:
    # %pip install control

import control as ctl
import numpy as np
import scipy.signal as sg
import numpy as np
import matplotlib.pyplot as plt

print("QUESTÃO 2")
#2 - Forma explícita da constante de tempo
#Letra a
n = [1]
d = [0.5, 1]
G1 = ctl.tf(n, d)
print(G1)

#Letra B
n = [1]
d = [1, 1]
G2 = ctl.tf(n, d)
print(G2)
#Letra C
n = [1]
d = [10, 1]
G3 = ctl.tf(n, d)
print(G3)
#Letra B'
n = [1]
d = [1/2, 1/2]
G4 = ctl.tf(n, d)
print(G4)
#Letra C'
n = [1]
d = [5, 1/2]
G5 = ctl.tf(n, d)
print(G5)
#
polos = ctl.poles(G1) #calcula os polos da função
zeros = ctl.zeros(G1) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

polos2 = ctl.poles(G2) #calcula os polos da função
zeros2 = ctl.zeros(G2) #calcula os polos da função

print('Polos : ',polos2)  #Imprime os polos
print('Zeros : ',zeros2)  #Imprime os zeros

polos4 = ctl.poles(G4) #calcula os polos da função
zeros4 = ctl.zeros(G4) #calcula os polos da função

print('Polos : ',polos4)  #Imprime os polos
print('Zeros : ',zeros4)  #Imprime os zeros

polos5 = ctl.poles(G5) #calcula os polos da função
zeros5 = ctl.zeros(G5) #calcula os polos da função

print('Polos : ',polos5)  #Imprime os polos
print('Zeros : ',zeros5)  #Imprime os zeros

#Fs = ctl.pzmap(G1,1, 0, 'Diagrama de Polos e Zeros') #Monta o diagrama de polos e zeros

#G = ctl.rss(4)
T1, yout1 = ctl.step_response(G1, 5)

plt.plot(T1, yout1, 'r') #cria uma figura
plt.grid()
plt.show()

T2, yout2 = ctl.step_response(G2, 5)

plt.plot(T2, yout2, 'b') #cria uma figura
plt.grid()
plt.show()

T, yout = ctl.step_response(G3, 60)

plt.plot(T, yout, 'g') #cria uma figura
plt.grid()
plt.show()

T, yout = ctl.step_response(G4, 5)
plt.plot(T, yout, 'r') #cria uma figura
plt.grid()
plt.show()

T, yout = ctl.step_response(G5, 60)
plt.plot(T, yout, 'b') #cria uma figura
plt.grid()
plt.show()

fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 linha, 2 colunas

# Plotando a resposta ao degrau para o sistema G1
axs[0].plot(T1, yout1, 'r')
axs[0].set_title('Resposta ao Degrau - G1')
axs[0].grid()

# Plotando a resposta ao degrau para o sistema G2
axs[1].plot(T2, yout2, 'b')
axs[1].set_title('Resposta ao Degrau - G2')
axs[1].grid()

# Ajustando o layout dos subplots
plt.tight_layout()

# Exibindo os gráficos
plt.show()
# Out:
# QUESTÃO 2
#
#     1
# ---------
# 0.5 s + 1
#
#
#   1
# -----
# s + 1
#
#
#    1
# --------
# 10 s + 1
#
#
#      1
# -----------
# 0.5 s + 0.5
#
#
#     1
# ---------
# 5 s + 0.5
#
# Polos :  [-2.+0.j]
# Zeros :  []
# Polos :  [-1.+0.j]
# Zeros :  []
# Polos :  [-1.+0.j]
# Zeros :  []
# Polos :  [-0.1+0.j]
# Zeros :  []

# %%
#3- Forma explícita do polo
print("QUESTÃO 3")
#Letra a
n = [1]
d = [1, 1]
G1 = ctl.tf(n, d)
print(G1)

polos = ctl.poles(G1) #calcula os polos da função
zeros = ctl.zeros(G1) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T1, yout1 = ctl.step_response(G1, 7)

plt.plot(T1, yout1, 'r') #cria uma figura
plt.grid()
#####################
n = [1]
d = [1, 2]
G2 = ctl.tf(n, d)
print(G2)

polos = ctl.poles(G2) #calcula os polos da função
zeros = ctl.zeros(G2) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T2, yout2 = ctl.step_response(G2, 7)
plt.plot(T2, yout2, 'b') #cria uma figura
#####################
n = [1]
d = [1, 10]
G3 = ctl.tf(n, d)
print(G3)

polos = ctl.poles(G3) #calcula os polos da função
zeros = ctl.zeros(G3) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T3, yout3 = ctl.step_response(G3, 7)
plt.plot(T3, yout3, 'g') #cria uma figura
plt.show()
#####################
n = [1]
d = [1, 1]
G4 = ctl.tf(n, d)
print(G4)

polos = ctl.poles(G4) #calcula os polos da função
zeros = ctl.zeros(G4) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T4, yout4 = ctl.step_response(G4, 7)

plt.plot(T4, yout4, 'r') #cria uma figura
plt.grid()
#####################
n = [2]
d = [1, 1]
G5 = ctl.tf(n, d)
print(G5)

polos = ctl.poles(G5) #calcula os polos da função
zeros = ctl.zeros(G5) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T5, yout5 = ctl.step_response(G5, 7)
plt.plot(T5, yout5, 'b') #cria uma figura
#####################
n = [10]
d = [1, 1]
G6 = ctl.tf(n, d)
print(G6)

polos = ctl.poles(G6) #calcula os polos da função
zeros = ctl.zeros(G6) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T6, yout6 = ctl.step_response(G6, 7)
plt.plot(T6, yout6, 'g') #cria uma figura
plt.show()
#####################
# Out:
# QUESTÃO 3
#
#   1
# -----
# s + 1
#
# Polos :  [-1.+0.j]
# Zeros :  []
#
#   1
# -----
# s + 2
#
# Polos :  [-2.+0.j]
# Zeros :  []
#
#   1
# ------
# s + 10
#
# Polos :  [-10.+0.j]
# Zeros :  []
#   1
# -----
# s + 1
#
# Polos :  [-1.+0.j]
# Zeros :  []
#
#   2
# -----
# s + 1
#
# Polos :  [-1.+0.j]
# Zeros :  []
#
#  10
# -----
# s + 1
#
# Polos :  [-1.+0.j]
# Zeros :  []

# %%
#4 - Determinação da função de transferência
print("QUESTÃO 4")
#Letra a
n = [3]
d = [2, 1]
G1 = ctl.tf(n, d)
print(G1)

polos = ctl.poles(G1) #calcula os polos da função
zeros = ctl.zeros(G1) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T1, yout1 = ctl.step_response(G1, 50)
plt.plot(T1, yout1, 'r') #cria uma figura
plt.grid()

#Letra b
n = [3]
d = [4, 1]
G2 = ctl.tf(n, d)
print(G2)

polos = ctl.poles(G2) #calcula os polos da função
zeros = ctl.zeros(G2) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T2, yout2 = ctl.step_response(G2, 50)
plt.plot(T2, yout2, 'g') #cria uma figura
plt.plot(T,np.ones(len(T))*0.63*3,'k' ,linestyle='--',
         label='63%')

print("Polos mais próximos de 0 tem uma resposta mais lenta")
########################################
# Out:
# QUESTÃO 4
#
#    3
# -------
# 2 s + 1
#
# Polos :  [-0.5+0.j]
# Zeros :  []
#
#    3
# -------
# 4 s + 1
#
# Polos :  [-0.25+0.j]
# Zeros :  []
# Polos mais próximos de 0 tem uma resposta mais lenta

# %%
#3- Forma explícita do polo
print("QUESTÃO 5")
#Letra a
r1 = 10**3
r2 = 10**4
r3 = 10**5
c = 10*10**-6
c2 = 10**-6

n = [1]
d = [r1, 1/c]
G1 = ctl.tf(n, d)
print(G1)

polos = ctl.poles(G1) #calcula os polos da função
zeros = ctl.zeros(G1) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T1, yout1 = ctl.step_response(G1, 1)
plt.plot(T1, yout1, 'r', label='R =   1kΩ') #cria uma figura
##############
n = [1]
d = [r2, 1/c]
G2 = ctl.tf(n, d)
print(G1)

polos = ctl.poles(G2) #calcula os polos da função
zeros = ctl.zeros(G2) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T2, yout2 = ctl.step_response(G2, 1)
plt.plot(T2, yout2, 'b', label='R =   10kΩ') #cria uma figura
##############
n = [1]
d = [r3, 1/c]
G3 = ctl.tf(n, d)
print(G3)

polos = ctl.poles(G3) #calcula os polos da função
zeros = ctl.zeros(G3) #calcula os polos da função

print('Polos : ',polos)  #Imprime os polos
print('Zeros : ',zeros)  #Imprime os zeros

T3, yout3 = ctl.step_response(G3, 1)
plt.plot(T3, yout3, 'b', label='R =   100kΩ') #cria uma figura
plt.grid()
plt.legend()
################
# Out:
# QUESTÃO 5
#
#       1
# --------------
# 1000 s + 1e+05
#
# Polos :  [-100.+0.j]
# Zeros :  []
#
#       1
# --------------
# 1000 s + 1e+05
#
# Polos :  [-10.+0.j]
# Zeros :  []
#
#        1
# ---------------
# 1e+05 s + 1e+05
#
# Polos :  [-1.+0.j]
# Zeros :  []
